# %% [markdown]
# # Python | Pandas DataFrame

# %% [markdown]
# ### What is Pandas?

# %% [markdown]
# <b>pandas</b> is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.

# %% [markdown]
# ### What is a Pandas DataFrame?

# %% [markdown]
# <b>Pandas DataFrame</b> is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
#
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %% [markdown]
# <img src="images/pandas.jpg">

# %% [markdown]
# A Pandas DataFrame will be created by loading the datasets from existing storage. Storage can be SQL Database, CSV file, and Excel file.
# Pandas DataFrame can be created from the lists, dictionary, and from a list of dictionary etc.
#
# Dataframe can be created in different ways here are some ways by which we create a dataframe:

# %% [markdown]
# ### Creating a dataframe using List:

# %%
# import pandas as pd
import pandas as pd
 
# list of strings
lyst = ['CSC', '102', 'is', 'the', 'best', 'course', 'ever']
 
# Calling DataFrame constructor on list
df = pd.DataFrame(lyst)

# Print the output.
df
# Out:
#         0
# 0     CSC
# 1     102
# 2      is
# 3     the
# 4    best
# 5  course
# 6    ever

# %% [markdown]
# ### Creating a dataframe using dict of narray/lists:

# %%
import pandas as pd
 
# intialise data of lists.
data = {'Name':['Angel', 'Precious', 'Kishi', 'Love'],
        'Age':['20', '21', '19', '18']}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
df
# Out:
#        Name Age
# 0     Angel  20
# 1  Precious  21
# 2     Kishi  19
# 3      Love  18

# %% [markdown]
# ### Column Selection:

# %%
# Import pandas package
import pandas as pd
 
# Define a dictionary containing employee data
data = {'Name':['Clement', 'Prince', 'Karol', 'Adaobi'],
        'Age':[27, 24, 22, 32],
        'Address':['Abuja', 'Kano', 'Minna', 'Lagos'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
# Convert the dictionary into DataFrame 
df = pd.DataFrame(data)
 
# select two columns
df[['Name', 'Qualification']]
# Out:
#       Name Qualification
# 0  Clement           Msc
# 1   Prince            MA
# 2    Karol           MCA
# 3   Adaobi           Phd

# %% [markdown]
# ### Row Selection:
# Pandas provide a unique method to retrieve rows from a Data frame.<br>
# <i><font color="green">DataFrame.iloc[]</font></i> method is used to retrieve rows from Pandas DataFrame.<br>

# %%
import pandas as pg
 
# Define a dictionary containing employee data
data = {'Name':['Oyinda', 'Maryam', 'Dumebi', 'Bisola'],
        'Age':[27, 24, 22, 32],
        'Address':['Asaba', 'Maiduguri', 'Onitsha', 'Kwara'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 
# Convert the dictionary into DataFrame 
df = pg.DataFrame(data)
 
# select first row
df.iloc[0]
# Out:
# Name             Oyinda
# Age                  27
# Address           Asaba
# Qualification       Msc
# Name: 0, dtype: object

# %% [markdown]
# ### Read from a file:

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("bcg.csv")

# print excel
data
# Out:
#     Employee Names  Years  Assesment Records  Points  Reward
# 0      Matthew Ade     25              125.3      21  438.55
# 1   Angela Adebisi     15               77.9      14  181.77
# 2  Calistus Ndukwe     10              144.2      18  432.60
# 3   Martha Martins      9               81.5      25  339.58
# 4    Victor Sayola     18               77.8      33  427.90
# 5      Adamu Bello     23               99.5      24  398.00

# %% [markdown]
# ### Select first row from file

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("bcg.csv")

df = data.iloc[0]

# print excel
df
# Out:
# Employee Names       Matthew Ade
# Years                         25
# Assesment Records          125.3
# Points                        21
# Reward                    438.55
# Name: 0, dtype: object

# %% [markdown]
# ### Selecting Row with Title Header

# %%
# importing pandas package
import pandas as pd
 
# making data frame from csv file
data = pd.read_csv("bcg.csv")

df=data.head(1)

# print excel
df
# Out:
#   Employee Names  Years  Assesment Records  Points  Reward
# 0    Matthew Ade     25              125.3      21  438.55

# %% [markdown]
# ### Looping over rows and columns
# A loop is a general term for taking each item of something, one after another.<br> Pandas DataFrame consists of rows and columns so, in order to loop over dataframe, we have to iterate a dataframe like a dictionary.<br><br>
# In order to iterate over rows, we can use two functions <i><font color="green">iteritems(), iterrows() </font></i>. These two functions will help in iteration over rows.

# %%
# importing pandas as pd
import pandas as pd
  
# dictionary of lists
dict = {'name':["Abdurrahman", "Chukwuemeka", "Somebi", "Michael", "Dejo"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA", "BSC"],
        'score':['90', '40', '80', '98', '99']}
 
# creating a dataframe from a dictionary 
df = pd.DataFrame(dict)

# iterating over rows using iterrows() function 
for i, j in df.iterrows():
    print(i, j)
    print()
# Out:
# 0 name      Abdurrahman
# degree            MBA
# score              90
# Name: 0, dtype: object
#
# 1 name      Chukwuemeka
# degree            BCA
# score              40
# Name: 1, dtype: object
#
# 2 name      Somebi
# degree    M.Tech
# score         80
# Name: 2, dtype: object
#
# 3 name      Michael
# degree        MBA
# score          98
# Name: 3, dtype: object
#
# 4 name      Dejo
# degree     BSC
# score       99
# Name: 4, dtype: object

# %% [markdown]
# ### Looping over Columns :
# In order to loop over columns, we need to create a list of dataframe columns and then iterating through that list to pull out the dataframe columns.

# %%
# importing pandas as pd
import pandas as pd
   
# dictionary of lists
dict = {'name':["Bimpe", "Kamara", "Ugochi", "David"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
  
# creating a dataframe from a dictionary 
df = pd.DataFrame(dict)

# creating a list of dataframe columns
columns = list(df)
 
for i in columns:
 
    # printing the third element of the column
    print (df[i][2])
# Out:
# Ugochi
# M.Tech
# 80

# %% [markdown]
# ### Saving a DataFrame as CSV file

# %%
# importing pandas as pd
import pandas as pd
   
# dictionary of lists
blades = {'name':["Ebube", "Kamsi", "Oyinkan", "Chima"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':["90", "40", "80", "98"]}
  
# creating a dataframe from a dictionary 
df = pd.DataFrame(blades)

# saving the dataframe
df.to_csv('blade1.csv')

# %% [markdown]
# ## Solution to Question II

# %%
# importing pandas as pd
import pandas as pd

data = pd.DataFrame({'Employee Names':['Alegbe Luis', 'Anna Mabuta', 'Karim Kafi', 'Esther Moses', 'Jonah Longe', 'Coins Fagbemi'],
                     "Years":['5','10','15','8','4','20'], 
                     "Assesment Records": ['44.5','67.4','23.8','71.1','50.3','63.3'],
                    })
data
# Out:
#   Employee Names Years Assesment Records
# 0    Alegbe Luis     5              44.5
# 1    Anna Mabuta    10              67.4
# 2     Karim Kafi    15              23.8
# 3   Esther Moses     8              71.1
# 4    Jonah Longe     4              50.3
# 5  Coins Fagbemi    20              63.3

# %%
points=[]
rewards=[]
len = 6

access_rec = data['Assesment Records']
for i in range(len):
    if (access_rec[i] < 40.0 ):
        point = 1
    elif (access_rec[i] > 39.0 and access_rec[i] < 50.0 ):
        point = 2
    elif (access_rec[i] > 49.0 and access_rec[i] < 60.0):
        point = 3
    elif (access_rec[i] > 59.0 and access_rec[i] < 70.0):
        point = 4
    else:
        point = 5
    
    reward = (access_rec[i]*point/6)
    points.append(point)
    rewards.append("%.2f" % reward)    
    
data['Points']=(points)
data['Rewards']=(rewards)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\TESTIM~1\AppData\Local\Temp/ipykernel_15692/14888940.py in <module>
#      16         point = '5'
#      17
# ---> 18     reward = (access_rec[i]*point/6)
#      19     points.append(point)
#      20     rewards.append("%.2f" % reward)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
# Save to excel(csv)
data.to_csv('bcg_records.csv')

# %% [markdown]
# ## Class Project I

# %% [markdown]
# ####  Go to www.kaggle.com
#
# Kaggle allows users to find and publish data sets, explore and build models in a web-based data-science environment, work with other data scientists and machine learning engineers, and enter competitions to solve data science challenges.
#
# #### Download the following dataset:
# 1. Top Apps in Google Play
# 2. Cryptocurrency Predict Artificial Intelligence V3
# 3. Programming Laungages and File Format Detection
#
# #### Clue
# You can signin with either Google, facebook or Linkedin account
#
# #### Task
# Display the first 7 rows of each dataset<br>
# Select the first 3 colums of each dataset<br>
# Display only one row and header of each dataset

# %%
#First Three Columns
import pandas as pd
l = f.head(2)
l
# Out:
#    Unnamed: 0              App Name                      App Id  \
# 0           1  Google Play services      com.google.android.gms
# 1           2               YouTube  com.google.android.youtube
#
#                   Category Developer Id  \
# 0                    Tools   Google LLC
# 1  Video Players & Editors   Google LLC
#
#                                    Developer Website  \
# 0  https://developers.google.com/android/google-p...
# 1  https://support.google.com/youtube/topic/24225...
#
#                 Developer Email Content Rating  Ad Supported  In App Purchases
# 0          apps-help@google.com       Everyone         False             False
# 1  ytandroid-support@google.com           Teen          True             False

# %%
#One Row and Header of Each set
for i in f.iterrows():
    print(f.iloc(0), i)
    print()
# Out:
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1C5450> (0, Unnamed: 0                                                           1
# App Name                                          Google Play services
# App Id                                          com.google.android.gms
# Category                                                         Tools
# Developer Id                                                Google LLC
# Developer Website    https://developers.google.com/android/google-p...
# Developer Email                                   apps-help@google.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                 False
# Name: 0, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C310> (1, Unnamed: 0                                                           2
# App Name                                                       YouTube
# App Id                                      com.google.android.youtube
# Category                                       Video Players & Editors
# Developer Id                                                Google LLC
# Developer Website    https://support.google.com/youtube/topic/24225...
# Developer Email                           ytandroid-support@google.com
# Content Rating                                                    Teen
# Ad Supported                                                      True
# In App Purchases                                                 False
# Name: 1, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1C5450> (2, Unnamed: 0                                                 3
# App Name                                              Google
# App Id               com.google.android.googlequicksearchbox
# Category                                               Tools
# Developer Id                                      Google LLC
# Developer Website       https://www.google.com/search/about/
# Developer Email                         apps-help@google.com
# Content Rating                                      Everyone
# Ad Supported                                            True
# In App Purchases                                       False
# Name: 2, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028810> (3, Unnamed: 0                                          4
# App Name             Google Maps - Navigate & Explore
# App Id                   com.google.android.apps.maps
# Category                               Travel & Local
# Developer Id                               Google LLC
# Developer Website       http://maps.google.com/about/
# Developer Email                  apps-help@google.com
# Content Rating                               Everyone
# Ad Supported                                     True
# In App Purchases                                False
# Name: 3, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1AABD0> (4, Unnamed: 0                                 5
# App Name               Google Text-to-Speech
# App Id                com.google.android.tts
# Category                               Tools
# Developer Id                      Google LLC
# Developer Website     http://www.google.com/
# Developer Email      tts-feedback@google.com
# Content Rating                      Everyone
# Ad Supported                           False
# In App Purchases                       False
# Name: 4, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C310> (5, Unnamed: 0                                              6
# App Name                     Google Chrome: Fast & Secure
# App Id                                 com.android.chrome
# Category                                    Communication
# Developer Id                                   Google LLC
# Developer Website    http://www.google.com/chrome/android
# Developer Email                      apps-help@google.com
# Content Rating                                   Everyone
# Ad Supported                                        False
# In App Purchases                                    False
# Name: 5, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F34540> (6, Unnamed: 0                                                           7
# App Name                                                         Gmail
# App Id                                           com.google.android.gm
# Category                                                 Communication
# Developer Id                                                Google LLC
# Developer Website    http://support.google.com/mail/bin/topic.py?hl...
# Developer Email                                   apps-help@google.com
# Content Rating                                                Everyone
# Ad Supported                                                      True
# In App Purchases                                                 False
# Name: 6, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C310> (7, Unnamed: 0                                                           8
# App Name                                   Android Accessibility Suite
# App Id                              com.google.android.marvin.talkback
# Category                                                         Tools
# Developer Id                                                Google LLC
# Developer Website    https://developer.android.com/guide/topics/ui/...
# Developer Email                                   apps-help@google.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                 False
# Name: 7, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469EDFD10> (8, Unnamed: 0                                                           9
# App Name                                                  Google Drive
# App Id                                    com.google.android.apps.docs
# Category                                                  Productivity
# Developer Id                                                Google LLC
# Developer Website    https://support.google.com/drive/?p=android_dr...
# Developer Email                                   apps-help@google.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                  True
# Name: 8, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C310> (9, Unnamed: 0                                          10
# App Name                                      Facebook
# App Id                             com.facebook.katana
# Category                                        Social
# Developer Id                                  Facebook
# Developer Website    https://www.facebook.com/facebook
# Developer Email                facebook.android@fb.com
# Content Rating                                    Teen
# Ad Supported                                      True
# In App Purchases                                  True
# Name: 9, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028810> (10, Unnamed: 0                                     11
# App Name                       WhatsApp Messenger
# App Id                               com.whatsapp
# Category                            Communication
# Developer Id                         WhatsApp LLC
# Developer Website        http://www.whatsapp.com/
# Developer Email      android@support.whatsapp.com
# Content Rating                           Everyone
# Ad Supported                                False
# In App Purchases                            False
# Name: 10, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1BAEA0> (11, Unnamed: 0                                                12
# App Name             Google TV (previously Play Movies & TV)
# App Id                             com.google.android.videos
# Category                             Video Players & Editors
# Developer Id                                      Google LLC
# Developer Website       http://support.google.com/googleplay
# Developer Email                         apps-help@google.com
# Content Rating                                          Teen
# Ad Supported                                           False
# In App Purchases                                       False
# Name: 11, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C900> (12, Unnamed: 0                                          13
# App Name                                 Google Photos
# App Id                  com.google.android.apps.photos
# Category                                   Photography
# Developer Id                                Google LLC
# Developer Website    https://support.google.com/photos
# Developer Email                   apps-help@google.com
# Content Rating                                Everyone
# Ad Supported                                     False
# In App Purchases                                 False
# Name: 12, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1B5860> (13, Unnamed: 0                                                          14
# App Name                      Messenger – Text and Video Chat for Free
# App Id                                               com.facebook.orca
# Category                                                 Communication
# Developer Id                                                  Facebook
# Developer Website    https://www.facebook.com/games/fbmessenger_and...
# Developer Email                                 android-support@fb.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                  True
# Name: 13, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C900> (14, Unnamed: 0                                                          15
# App Name                                                      Hangouts
# App Id                                         com.google.android.talk
# Category                                                 Communication
# Developer Id                                                Google LLC
# Developer Website    https://support.google.com/hangouts/?p=android...
# Developer Email                                   apps-help@google.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                 False
# Name: 14, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C310> (15, Unnamed: 0                                   16
# App Name                 Android System WebView
# App Id               com.google.android.webview
# Category                                  Tools
# Developer Id                         Google LLC
# Developer Website        http://www.android.com
# Developer Email            apps-help@google.com
# Content Rating                         Everyone
# Ad Supported                              False
# In App Purchases                          False
# Name: 15, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469EDC7C0> (16, Unnamed: 0                                                        17
# App Name                                           Google Play Games
# App Id                                 com.google.android.play.games
# Category                                               Entertainment
# Developer Id                                              Google LLC
# Developer Website    http://play.google.com/store/apps/category/GAME
# Developer Email                        googleplay-support@google.com
# Content Rating                                                  Teen
# Ad Supported                                                   False
# In App Purchases                                               False
# Name: 16, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469B4A540> (17, Unnamed: 0                                       18
# App Name                       Samsung Push Service
# App Id                             com.sec.spp.push
# Category                              Communication
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email             noreply.sec@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 17, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469EDC7C0> (18, Unnamed: 0                                              19
# App Name             Google Duo - High Quality Video Calls
# App Id                     com.google.android.apps.tachyon
# Category                                     Communication
# Developer Id                                    Google LLC
# Developer Website                      https://google.com/
# Developer Email                       apps-help@google.com
# Content Rating                                    Everyone
# Ad Supported                                         False
# In App Purchases                                     False
# Name: 18, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A13CF90> (19, Unnamed: 0                                                          20
# App Name                                                      Currents
# App Id                                    com.google.android.apps.plus
# Category                                                        Social
# Developer Id                                                Google LLC
# Developer Website    https://support.google.com/plus/?hl=en#topic=6...
# Developer Email                                   apps-help@google.com
# Content Rating                                                    Teen
# Ad Supported                                                     False
# In App Purchases                                                 False
# Name: 19, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1B5860> (20, Unnamed: 0                                             21
# App Name                     Gboard - the Google Keyboard
# App Id               com.google.android.inputmethod.latin
# Category                                            Tools
# Developer Id                                   Google LLC
# Developer Website       https://support.google.com/gboard
# Developer Email             gboard-dev-support@google.com
# Content Rating                                   Everyone
# Ad Supported                                        False
# In App Purchases                                    False
# Name: 20, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F1CCC0> (21, Unnamed: 0                                      22
# App Name                                 Instagram
# App Id                       com.instagram.android
# Category                                    Social
# Developer Id                             Instagram
# Developer Website       http://help.instagram.com/
# Developer Email      android-support@instagram.com
# Content Rating                                Teen
# Ad Supported                                  True
# In App Purchases                              True
# Name: 21, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A12AF90> (22, Unnamed: 0                                                          23
# App Name             Google Play Books - Ebooks, Audiobooks, and Co...
# App Id                                   com.google.android.apps.books
# Category                                             Books & Reference
# Developer Id                                                Google LLC
# Developer Website                              http://play.google.com/
# Developer Email                          googleplay-support@google.com
# Content Rating                                                    Teen
# Ad Supported                                                     False
# In App Purchases                                                 False
# Name: 22, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A11FA90> (23, Unnamed: 0                                                       24
# App Name             Google News - Top world & local news headlines
# App Id                            com.google.android.apps.magazines
# Category                                           News & Magazines
# Developer Id                                             Google LLC
# Developer Website                     https://news.google.com/about
# Developer Email                                apps-help@google.com
# Content Rating                                                 Teen
# Ad Supported                                                   True
# In App Purchases                                              False
# Name: 23, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A12AF90> (24, Unnamed: 0                                                        25
# App Name                                             Google Calendar
# App Id                                   com.google.android.calendar
# Category                                                Productivity
# Developer Id                                              Google LLC
# Developer Website    http://support.google.com/calendar?p=mobilesync
# Developer Email                                 apps-help@google.com
# Content Rating                                              Everyone
# Ad Supported                                                   False
# In App Purchases                                               False
# Name: 24, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A11FA90> (25, Unnamed: 0                                        26
# App Name                    Samsung Internet Browser
# App Id                  com.sec.android.app.sbrowser
# Category                               Communication
# Developer Id          Samsung Electronics Co.,  Ltd.
# Developer Website    http://help.content.samsung.com
# Developer Email              noreply.sec@samsung.com
# Content Rating                              Everyone
# Ad Supported                                   False
# In App Purchases                               False
# Name: 25, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1B5860> (26, Unnamed: 0                                       27
# App Name                        Samsung One UI Home
# App Id                 com.sec.android.app.launcher
# Category                            Personalization
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email             noreply.sec@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 26, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A11FA90> (27, Unnamed: 0                                       28
# App Name                            Samsung Gallery
# App Id                    com.sec.android.gallery3d
# Category                                Photography
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email             noreply.sec@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 27, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469EDFD10> (28, Unnamed: 0                                          29
# App Name                                 Facebook Lite
# App Id                               com.facebook.lite
# Category                                        Social
# Developer Id                                  Facebook
# Developer Website    https://www.facebook.com/facebook
# Developer Email            lite-android-support@fb.com
# Content Rating                                    Teen
# Ad Supported                                      True
# In App Purchases                                 False
# Name: 28, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028A40> (29, Unnamed: 0                                       30
# App Name                           Samsung My Files
# App Id                  com.sec.android.app.myfiles
# Category                                      Tools
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email             noreply.sec@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 29, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028810> (30, Unnamed: 0                                         31
# App Name                           Microsoft OneDrive
# App Id                         com.microsoft.skydrive
# Category                                 Productivity
# Developer Id                    Microsoft Corporation
# Developer Website    https://aka.ms/OneDriveOnAndroid
# Developer Email                odrvhelp@microsoft.com
# Content Rating                               Everyone
# Ad Supported                                    False
# In App Purchases                                 True
# Name: 30, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469EDC7C0> (31, Unnamed: 0                                               32
# App Name                                       Android Auto
# App Id               com.google.android.projection.gearhead
# Category                                    Auto & Vehicles
# Developer Id                                     Google LLC
# Developer Website               http://www.android.com/auto
# Developer Email                 android-auto-app@google.com
# Content Rating                                         Teen
# Ad Supported                                          False
# In App Purchases                                      False
# Name: 31, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028810> (32, Unnamed: 0                                              33
# App Name                                          Messages
# App Id                   com.google.android.apps.messaging
# Category                                     Communication
# Developer Id                                    Google LLC
# Developer Website    http://www.google.com/mobile/android/
# Developer Email                       apps-help@google.com
# Content Rating                                    Everyone
# Ad Supported                                         False
# In App Purchases                                     False
# Name: 32, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469EDC7C0> (33, Unnamed: 0                               34
# App Name                   Carrier Services
# App Id               com.google.android.ims
# Category                      Communication
# Developer Id                     Google LLC
# Developer Website       https://google.com/
# Developer Email        apps-help@google.com
# Content Rating                     Everyone
# Ad Supported                          False
# In App Purchases                      False
# Name: 33, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F1CCC0> (34, Unnamed: 0                                      35
# App Name             Skype - free IM & video calls
# App Id                            com.skype.raider
# Category                             Communication
# Developer Id                                 Skype
# Developer Website             http://www.skype.com
# Developer Email       skypeuploader@googlemail.com
# Content Rating                            Everyone
# Ad Supported                                 False
# In App Purchases                             False
# Name: 34, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A13CA40> (35, Unnamed: 0                                           36
# App Name                             Google Street View
# App Id                        com.google.android.street
# Category                                 Travel & Local
# Developer Id                                 Google LLC
# Developer Website    http://www.google.com/mobile/maps/
# Developer Email                    apps-help@google.com
# Content Rating                                 Everyone
# Ad Supported                                      False
# In App Purchases                                  False
# Name: 35, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1B5860> (36, Unnamed: 0                                       37
# App Name                             Subway Surfers
# App Id                         com.kiloo.subwaysurf
# Category                                     Arcade
# Developer Id                             SYBO Games
# Developer Website            https://sybogames.com/
# Developer Email      subwaysurfers@sybo.zendesk.com
# Content Rating                         Everyone 10+
# Ad Supported                                   True
# In App Purchases                               True
# Name: 36, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F2C900> (37, Unnamed: 0                                          38
# App Name                    Samsung Experience Service
# App Id               com.samsung.android.mobileservice
# Category                                         Tools
# Developer Id            Samsung Electronics Co.,  Ltd.
# Developer Website          http://www.samsung.com/sec/
# Developer Email                noreply.sec@samsung.com
# Content Rating                                    Teen
# Ad Supported                                     False
# In App Purchases                                 False
# Name: 37, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028A40> (38, Unnamed: 0                                       39
# App Name                                Device Care
# App Id                     com.samsung.android.lool
# Category                                      Tools
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email              smart.mngr@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 38, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028810> (39, Unnamed: 0                                          40
# App Name                    SHAREit - Transfer & Share
# App Id                         com.lenovo.anyshare.gps
# Category                                         Tools
# Developer Id         Smart Media4U Technology Pte.Ltd.
# Developer Website              http://www.ushareit.com
# Developer Email          feedback_android@ushareit.com
# Content Rating                                Everyone
# Ad Supported                                      True
# In App Purchases                                  True
# Name: 39, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F1CCC0> (40, Unnamed: 0                                                          41
# App Name             Microsoft Word: Write, Edit & Share Docs on th...
# App Id                                       com.microsoft.office.word
# Category                                                  Productivity
# Developer Id                                     Microsoft Corporation
# Developer Website                          https://products.office.com
# Developer Email                                 officean@microsoft.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                  True
# Name: 40, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469EDFD10> (41, Unnamed: 0                                 42
# App Name                               TikTok
# App Id               com.zhiliaoapp.musically
# Category                               Social
# Developer Id                 TikTok Pte. Ltd.
# Developer Website     https://www.tiktok.com/
# Developer Email           feedback@tiktok.com
# Content Rating                           Teen
# Ad Supported                             True
# In App Purchases                         True
# Name: 41, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F340E0> (42, Unnamed: 0                                43
# App Name                            Snapchat
# App Id                  com.snapchat.android
# Category                              Social
# Developer Id                        Snap Inc
# Developer Website    http://www.snapchat.com
# Developer Email            snapchat@snap.com
# Content Rating                          Teen
# Ad Supported                            True
# In App Purchases                        True
# Name: 42, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1BA8B0> (43, Unnamed: 0                                           44
# App Name                                  Samsung Email
# App Id               com.samsung.android.email.provider
# Category                                   Productivity
# Developer Id             Samsung Electronics Co.,  Ltd.
# Developer Website                   https://samsung.com
# Developer Email                     b2b.sec@samsung.com
# Content Rating                                 Everyone
# Ad Supported                                      False
# In App Purchases                                  False
# Name: 43, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028810> (44, Unnamed: 0                                            45
# App Name                              Samsung Calculator
# App Id               com.sec.android.app.popupcalculator
# Category                                           Tools
# Developer Id              Samsung Electronics Co.,  Ltd.
# Developer Website                    https://samsung.com
# Developer Email                  noreply.sec@samsung.com
# Content Rating                                  Everyone
# Ad Supported                                       False
# In App Purchases                                   False
# Name: 44, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1BFB30> (45, Unnamed: 0                                                          46
# App Name             Microsoft Excel: View, Edit, & Create Spreadsh...
# App Id                                      com.microsoft.office.excel
# Category                                                  Productivity
# Developer Id                                     Microsoft Corporation
# Developer Website                          https://products.office.com
# Developer Email                                 officean@microsoft.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                  True
# Name: 45, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A13CA40> (46, Unnamed: 0                                    47
# App Name                    ANT+ Plugins Service
# App Id               com.dsi.ant.plugins.antplus
# Category                                   Tools
# Developer Id                                ANT+
# Developer Website           http://thisisant.com
# Developer Email            android@thisisant.com
# Content Rating                          Everyone
# Ad Supported                               False
# In App Purchases                           False
# Name: 46, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A12AF90> (47, Unnamed: 0                                                          48
# App Name             Microsoft PowerPoint: Slideshows and Presentat...
# App Id                                 com.microsoft.office.powerpoint
# Category                                                  Productivity
# Developer Id                                     Microsoft Corporation
# Developer Website                          https://products.office.com
# Developer Email                                 officean@microsoft.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                  True
# Name: 47, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F1CCC0> (48, Unnamed: 0                                           49
# App Name                              ANT Radio Service
# App Id                       com.dsi.ant.service.socket
# Category                                  Communication
# Developer Id                                       ANT+
# Developer Website    http://www.thisisant.com/consumer/
# Developer Email                   android@thisisant.com
# Content Rating                                 Everyone
# Ad Supported                                      False
# In App Purchases                                  False
# Name: 48, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028A40> (49, Unnamed: 0                                       50
# App Name                     Samsung Voice Recorder
# App Id                com.sec.android.app.voicenote
# Category                                      Tools
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email             noreply.sec@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 49, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A11FA90> (50, Unnamed: 0                                          51
# App Name                   Google Play Services for AR
# App Id                              com.google.ar.core
# Category                                         Tools
# Developer Id                                Google LLC
# Developer Website    https://developers.google.com/ar/
# Developer Email              arcore-support@google.com
# Content Rating                                Everyone
# Ad Supported                                     False
# In App Purchases                                 False
# Name: 50, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028A40> (51, Unnamed: 0                                            52
# App Name                    Samsung Print Service Plugin
# App Id                   com.sec.app.samsungprintservice
# Category                                    Productivity
# Developer Id                                     HP Inc.
# Developer Website    https://www.samsung.com/us/printer/
# Developer Email            support@samsungcloudprint.com
# Content Rating                                  Everyone
# Ad Supported                                       False
# In App Purchases                                   False
# Name: 51, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A467A497C0> (52, Unnamed: 0                                53
# App Name                             Netflix
# App Id               com.netflix.mediaclient
# Category                       Entertainment
# Developer Id                   Netflix, Inc.
# Developer Website     http://www.netflix.com
# Developer Email        playstore@netflix.com
# Content Rating                          Teen
# Ad Supported                           False
# In App Purchases                        True
# Name: 52, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028A40> (53, Unnamed: 0                                       54
# App Name                              Secure Folder
# App Id                com.samsung.knox.securefolder
# Category                                   Business
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email               secfolder@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 53, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1B5860> (54, Unnamed: 0                                         55
# App Name                                     Briefing
# App Id                            flipboard.boxer.app
# Category                             News & Magazines
# Developer Id                                Flipboard
# Developer Website            http://www.flipboard.com
# Developer Email      play-store-support@flipboard.com
# Content Rating                           Everyone 10+
# Ad Supported                                     True
# In App Purchases                                False
# Name: 54, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1BA8B0> (55, Unnamed: 0                                                          56
# App Name                                                Samsung Health
# App Id                                     com.sec.android.app.shealth
# Category                                              Health & Fitness
# Developer Id                            Samsung Electronics Co.,  Ltd.
# Developer Website    https://www.samsung.com/global/galaxy/apps/sam...
# Developer Email                                noreply.sec@samsung.com
# Content Rating                                                Everyone
# Ad Supported                                                      True
# In App Purchases                                                 False
# Name: 55, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1B5860> (56, Unnamed: 0                                                 57
# App Name                        Google Keep - Notes and Lists
# App Id                                com.google.android.keep
# Category                                         Productivity
# Developer Id                                       Google LLC
# Developer Website    https://support.google.com/?p=notes_main
# Developer Email                          apps-help@google.com
# Content Rating                                       Everyone
# Ad Supported                                            False
# In App Purchases                                        False
# Name: 56, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028A40> (57, Unnamed: 0                                        58
# App Name                            Candy Crush Saga
# App Id                       com.king.candycrushsaga
# Category                                      Casual
# Developer Id                                    King
# Developer Website    http://candycrushsaga.com/help/
# Developer Email         candycrush.techhelp@king.com
# Content Rating                              Everyone
# Ad Supported                                    True
# In App Purchases                                True
# Name: 57, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028810> (58, Unnamed: 0                                          59
# App Name                               Files by Google
# App Id               com.google.android.apps.nbu.files
# Category                                         Tools
# Developer Id                                Google LLC
# Developer Website           http://filesgo.google.com/
# Developer Email              files-feedback@google.com
# Content Rating                                Everyone
# Ad Supported                                     False
# In App Purchases                                 False
# Name: 58, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A028A40> (59, Unnamed: 0                                                      60
# App Name                                                   Twitter
# App Id                                         com.twitter.android
# Category                                                    Social
# Developer Id                                         Twitter, Inc.
# Developer Website    https://support.twitter.com/articles/20169915
# Developer Email                     google-play-emails@twitter.com
# Content Rating                                          Mature 17+
# Ad Supported                                                  True
# In App Purchases                                             False
# Name: 59, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A467A497C0> (60, Unnamed: 0                                                          61
# App Name                                                   Google Docs
# App Id                       com.google.android.apps.docs.editors.docs
# Category                                                  Productivity
# Developer Id                                                Google LLC
# Developer Website    https://support.google.com/docs/?p=android_doc...
# Developer Email                                   apps-help@google.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                 False
# Name: 60, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F1CCC0> (61, Unnamed: 0                                              62
# App Name                                     YouTube Music
# App Id               com.google.android.apps.youtube.music
# Category                                     Music & Audio
# Developer Id                                    Google LLC
# Developer Website                https://music.youtube.com
# Developer Email                 ytmusic-support@google.com
# Content Rating                                        Teen
# Ad Supported                                          True
# In App Purchases                                     False
# Name: 61, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A467A497C0> (62, Unnamed: 0                                   63
# App Name                          YouTube Music
# App Id                 com.google.android.music
# Category                          Music & Audio
# Developer Id                         Google LLC
# Developer Website     https://music.youtube.com
# Developer Email      ytmusic-support@google.com
# Content Rating                             Teen
# Ad Supported                               True
# In App Purchases                          False
# Name: 62, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A12AF90> (63, Unnamed: 0                                                          64
# App Name             Dropbox: Cloud Storage, Photo Backup, File Man...
# App Id                                             com.dropbox.android
# Category                                                  Productivity
# Developer Id                                             Dropbox, Inc.
# Developer Website                              https://www.dropbox.com
# Developer Email                           android-feedback@dropbox.com
# Content Rating                                                Everyone
# Ad Supported                                                     False
# In App Purchases                                                  True
# Name: 63, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1BFCC0> (64, Unnamed: 0                                       65
# App Name             Samsung Security Policy Update
# App Id                                 com.policydm
# Category                               Productivity
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email              sw.upgrade@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 64, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F34540> (65, Unnamed: 0                                          66
# App Name                                         Clock
# App Id                    com.google.android.deskclock
# Category                                         Tools
# Developer Id                                Google LLC
# Developer Website               http://www.google.com/
# Developer Email      android-clock-feedback@google.com
# Content Rating                                Everyone
# Ad Supported                                     False
# In App Purchases                                 False
# Name: 65, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A469F340E0> (66, Unnamed: 0                                                          67
# App Name             Spotify: Listen to podcasts & find music you love
# App Id                                               com.spotify.music
# Category                                                 Music & Audio
# Developer Id                                              Spotify Ltd.
# Developer Website                              https://www.spotify.com
# Developer Email                            android-support@spotify.com
# Content Rating                                                    Teen
# Ad Supported                                                      True
# In App Purchases                                                 False
# Name: 66, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1B5860> (67, Unnamed: 0                                            68
# App Name                                Google Translate
# App Id                 com.google.android.apps.translate
# Category                                           Tools
# Developer Id                                  Google LLC
# Developer Website    http://support.google.com/translate
# Developer Email      translate-mobile-support@google.com
# Content Rating                                  Everyone
# Ad Supported                                       False
# In App Purchases                                   False
# Name: 67, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A1BFCC0> (68, Unnamed: 0                                       69
# App Name                              Samsung Notes
# App Id                com.samsung.android.app.notes
# Category                               Productivity
# Developer Id         Samsung Electronics Co.,  Ltd.
# Developer Website               https://samsung.com
# Developer Email             noreply.sec@samsung.com
# Content Rating                             Everyone
# Ad Supported                                  False
# In App Purchases                              False
# Name: 68, dtype: object)
#
# <pandas.core.indexing._iLocIndexer object at 0x000002A46A12AF90> (69, Unnamed: 0                                               70
# App Name                                         Calculator
# App Id                        com.google.android.calculator
# Category                                              Tools
# Developer Id                                     Google LLC
# Developer Website                    http://www.google.com/
# Developer Email      android-calculator-feedback@google.com
# Content Rating                                     Everyone
# Ad Supported                                          False
# In App Purchases                                      False
# Name: 69, dtype: object)

# %%
#First Seven Rows
import pandas as pd
t = pd.read_csv('Top-Apps-in-Google-Play.csv')
f = pd.DataFrame(t)

y = f.iloc[6]
y
# Out:
# Unnamed: 0                                                           7
# App Name                                                         Gmail
# App Id                                           com.google.android.gm
# Category                                                 Communication
# Developer Id                                                Google LLC
# Developer Website    http://support.google.com/mail/bin/topic.py?hl...
# Developer Email                                   apps-help@google.com
# Content Rating                                                Everyone
# Ad Supported                                                      True
# In App Purchases                                                 False
# Name: 6, dtype: object

# %% [markdown]
# ## Class Project II

# %% [markdown]
# <b>Cadbury Nigeria Plc</b> manufactures and sells branded fast moving consumer goods to the Nigerian market and exports in West Africa. The Company produces intermediate products, such as cocoa butter, liquor, cake and powder. It exports cocoa butter, cake and liquor to international customers, and cocoa powder locally. It operates through three segments: Refreshment Beverages, Confectionery and Intermediate Cocoa Products. The Refreshment Beverages segment includes the manufacture and sale of Bournvita and Hot Chocolate. The Confectionery segment includes the manufacture and sale of Tom Tom and Buttermint. The Intermediate Cocoa Products segment includes the manufacture and sale of cocoa powder, cocoa butter, cocoa liquor and cocoa cake. The Refreshment Beverages' brands include CADBURY BOURNVITA and CADBURY 3-in-1 HOT CHOCOLATE. The Confectionery's brands include TOMTOM CLASSIC, TOMTOM STRAWBERRY and BUTTERMINT. The Intermediate Cocoa Products' brands include COCOA POWDER and COCOA BUTTER.
#
# You have been employed as an expert python developer to create a program to document the consumption categories of their products and brands. Using your knowledge of Pandas DataFrames develop the program that saves the list of products (export, segments and brands) in a .csv excel file.<br><br>
# Hint: save the filename as <font color="green"><i>cadbury_market.csv</i></font>.

# %%
table = {'Refreshment Beverages':['Cadbury bournvita', 'Cadbury 3-in-1 Hot Chocolate', ""], 
         'Confectionery Brands':['TomTom Classic', 'TomTom Strawberry', 'Buttermint'], 
         'Intermediate Cocoa Products':['Cocoa Powder', 'Cocoa Butter', ""]}
tb = pd.DataFrame(table)
tb.to_csv("cadbury_market.csv")
